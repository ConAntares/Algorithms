# %% [markdown]
# # Julia Plots

# %% [markdown]
# ## 2D Plotting with PyPlot

# %%
using Plots; pyplot()
using LaTeXStrings

PyPlot.rc("text", usetex = "true")
PyPlot.rc("font", family = "CMU Serif")

X = range(-2pi, stop=2pi, length=100)
Y = 1.5 .* sin.(0.3 .+ 0.7X)

plot(dpi=256, gridls=:dash, legend=:topright, frame=:both,
     fgborder="blue", fgaxis="red", tickfontsize=10)
plot!(X,Y, title = L"Title $\alpha$", lw=2, label=L"wave $f=f(x)$", annotation=(1, 1, L"$\beta$"))
