# %% [markdown]
# # Julia PyPlot

# %% [markdown]
# ## 2D Plotting

# %%
using PyPlot

fig = figure("Title",figsize=(8,6))
X = range(-2pi, stop=2pi, length=100)
Y = sin.(X + 2*cos.(X))

plot(X,Y)
# Out:
# Figure(PyObject <Figure size 800x600 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000000F3F390>
